# %%
from selenium import webdriver
browser = webdriver.Chrome()

# %%
url="http://rate.am/en/armenian-dram-exchange-rates/banks/non-cash"

# %%
browser.get(url)

# %%
import pandas as pd

# %%
rates=browser.find_element_by_xpath('//*[@id="aspnetForm"]/div[3]/div[2]/div[1]/div[4]/div[3]/table/tbody/tr/td[1]/a')

# %%
rates.click()

# %%
rates_for_20july=browser.find_element_by_xpath('//*[@id="calBorder"]/span/table/tbody/tr[3]/td/table/tbody/tr[5]/td[4]')

# %%
rates_for_20july.click()

# %%
rates1=browser.find_element_by_xpath('//*[@id="ctl00_Content_RB_dtpick1_btnOk"]')

# %%
rates1.click()

# %%
rates_table=rates = pd.read_html(browser.find_element_by_class_name("rb").get_attribute('outerHTML'))

# %%
rates_table[0]
# Out:
#                                                    0                       1   \
# 0                                                 NaN                    Bank
# 1                                                 Buy                    Sell
# 2                                                  1.       Էյչ-Էս-Բի-Սի Բանկ
# 3                                                  2.               Յունիբանկ
# 4                                                  3.            Կոնվերս բանկ
# 5                                                  4.             Անելիք Բանկ
# 6                                                  5.       ՀԱՅԲԻԶՆԵՍԲԱՆԿ ՓԲԸ
# 7                                                  6.  ԱԿԲԱ-ԿՐԵԴԻՏ ԱԳՐԻԿՈԼ ..
# 8                                                  7.              Արդշինբանկ
# 9                                                  8.       ՎՏԲ-Հայաստան Բանկ
# 10                                                 9.               Ինեկոբանկ
# ...

# %%
our_table=rates[0]

# %%
rate_table1 = pd.DataFrame(our_table)

# %%
rate_table1.head()
# Out:
#     0                  1         2     3   \
# 0  NaN               Bank  Branches  Date
# 1  Buy               Sell       Buy  Sell
# 2   1.  Էյչ-Էս-Բի-Սի Բանկ       NaN     9
# 3   2.          Յունիբանկ       NaN    47
# 4   3.       Կոնվերս բանկ       NaN    35
#
#                                                   4   \
# 0  1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...
# 1                                                Buy
# 2                                      20 Jul, 20:01
# 3                                      20 Jul, 20:00
# 4                                      20 Jul, 20:00
#
#                                                   5   \
# 0  1 USD \t1 EUR \t1 RUR \t1 GBP \t1 GEL \t1 CHF ...
# 1                                               Sell
# 2                                             476.50
# 3                                             476.50
# 4                                             476.50
#
#                                                   6   \
# ...

# %%
rate_table1 = rate_table1.drop(2,axis=1)
rate_table1 = rate_table1.drop(3,axis=1)
rate_table1= rate_table1.drop(0,axis=1)
rate_table1 = rate_table1.drop(1,axis=0)
rate_table1 = rate_table1.drop(0,axis=0)
rate_table1.columns = ["Bank", "Date", "USD/buy", "USD/sell", "EUR/buy", "EUR/sell", "RUB/buy", "RUB/sell", "GBF/buy", "GBF/sell"]

# %%
rate_table1=rate_table1.drop(19, axis=0)

# %%
rate_table1
# Out:
#                       Bank           Date USD/buy USD/sell EUR/buy  EUR/sell  \
# 2        Էյչ-Էս-Բի-Սի Բանկ  20 Jul, 20:01  476.50   480.50     550     558.0
# 3                Յունիբանկ  20 Jul, 20:00  476.50      480     546     556.0
# 4             Կոնվերս բանկ  20 Jul, 20:00  476.50      480     547     555.0
# 5              Անելիք Բանկ  20 Jul, 20:00     477   480.50     546     556.0
# 6        ՀԱՅԲԻԶՆԵՍԲԱՆԿ ՓԲԸ  20 Jul, 20:00     477      480  547.10     554.1
# 7   ԱԿԲԱ-ԿՐԵԴԻՏ ԱԳՐԻԿՈԼ ..  20 Jul, 20:00     477   480.50  546.50     554.0
# 8               Արդշինբանկ  20 Jul, 20:00  477.50   480.50     548     558.0
# 9        ՎՏԲ-Հայաստան Բանկ  20 Jul, 20:00  477.25      480     547     553.5
# 10               Ինեկոբանկ  20 Jul, 20:00  477.25   480.25     547     559.0
# 11             Մելլաթ բանկ  20 Jul, 20:00     476      480     547     555.0
# 12     Բիբլոս Բանկ Արմենիա  20 Jul, 20:00     477   480.50     547     555.0
# ...

# %%
import csv

# %%
from unicodecsv import *
with open('table_rates.csv', 'w') as f:
            rate_table1.to_csv(f, header=True, index=False, encoding='utf-8')

# %%
data_csv = pd.read_csv("table_rates.csv")
data_csv.head()
# Out:
#                 Bank           Date  USD/buy  USD/sell  EUR/buy  EUR/sell  \
# 0  Էյչ-Էս-Բի-Սի Բանկ  20 Jul, 20:01    476.5     480.5    550.0     558.0
# 1          Յունիբանկ  20 Jul, 20:00    476.5     480.0    546.0     556.0
# 2       Կոնվերս բանկ  20 Jul, 20:00    476.5     480.0    547.0     555.0
# 3        Անելիք Բանկ  20 Jul, 20:00    477.0     480.5    546.0     556.0
# 4  ՀԱՅԲԻԶՆԵՍԲԱՆԿ ՓԲԸ  20 Jul, 20:00    477.0     480.0    547.1     554.1
#
#    RUB/buy  RUB/sell  GBF/buy  GBF/sell
# 0     7.99      8.23    616.5     625.5
# 1     8.00      8.25    612.0     632.0
# 2     8.02      8.21    619.0     627.0
# 3     8.04      8.22      NaN       NaN
# 4     8.02      8.24    617.1     629.1

# %%
browser.close()
